# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
from  dash import Dash, dcc, html, callback, Output, Input
#import dash_design_kit as ddk

# %%
df = pd.read_csv('gcpEconomicSectors.csv')
df.head()
# Out:
#             County  Agriculture_Forestry_and_Mining  Mining_and_Quarrying  \
# 0          BARINGO                            19385                   131
# 1            BOMET                            72044                   647
# 2          BUNGOMA                            73443                   294
# 3            BUSIA                            21951                   307
# 4  ELGEYO MARAKWET                            56910                   506
#
#    Manufacturing  Electricity_supply  Water_supply_waste_collection  \
# 0           4106                 114                            386
# 1          11928                 376                            629
# 2           7755                 653                           1387
# 3           2299                 201                            612
# 4           2248                 130                            270
#
#    Construction  Wholesale_and_Retail_trade_repair_of_motor_vehicles  \
# ...

# %%
app= Dash(__name__)

# %%
# Line Graph of GCP vs Year, with a dropdown County
app.layout = html.Div([
    html.H1(children='KENYA GROSS COUNTY PRODUCT(2018-2020)',style={'textAlign':'center'}),
    dcc.Dropdown(df.County.unique(), 'Baringo', id='dropdown-selection'),
    dcc.Graph(id='graph-content')
])

@callback(
    Output('graph-content','figure'),
    Input('dropdown-selection', 'value')
)
def update_graph(value):
    dff = df[df.County==value]
    return px.line(dff, x='Year', y='GCP')

# %%
fig = px.bar(df.County)
app.layout = html.Div(children=[
    html.Div(children='''Bar Graph''', style={'textAlign':'center'}),
    dcc.Graph(id='example-graph',
              figure=fig
    )
    
])

# %%
if __name__ == '__main__':
    app.run_server(debug=True, jupyter_mode='tab')
# Out:
# Dash app running on http://127.0.0.1:8050/
